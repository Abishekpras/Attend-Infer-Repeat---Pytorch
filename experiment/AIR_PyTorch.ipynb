# %% [markdown]
# <h3 align="center"><u>ATTEND INFER REPEAT</u></h3>

# %% [markdown]
# ![title](AIR.png)

# %% [markdown]
# <h3>1. Install all requirements</h3>
# <p>PyTorch, observations, PIL installation if non-existent already + creates data directory</p>

# %%
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag

platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install Pillow==4.0.0
# !pip install PIL
# !pip install image
# !pip install Pillow
# !pip install observations
# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.0-{platform}-linux_x86_64.whl torchvision
# !mkdir data

import torch
from PIL import Image

''' Ensure PyTorch version is 0.4.0 or higher ''''''
print(torch.__version__)

''' If using GPU, ensure cuda is available (True) '''
use_cuda = torch.cuda.is_available()
print('Torch device - GPU' if use_cuda else 'Torch device - CPU')
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\wheel\pep425tags.py:77: RuntimeWarning: Config variable 'Py_DEBUG' is unset, Python ABI tag may be incorrect
#   warn=(impl == 'cp')):
# C:\Program Files\Anaconda3\lib\site-packages\wheel\pep425tags.py:81: RuntimeWarning: Config variable 'WITH_PYMALLOC' is unset, Python ABI tag may be incorrect
#   warn=(impl == 'cp')):

# %%
# %%bash
#
# pip install Pillow==4.0.0
# pip install PIL
# pip install image
# pip install Pillow
# pip install observations
# pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
# mkdir data
# Out:
# Couldn't find program: 'bash'

# %%
import torch
from PIL import Image

''' Ensure PyTorch version is 0.4.0 or higher '''
print(torch.__version__)

''' If using GPU, ensure cuda is available (True) '''
use_cuda = torch.cuda.is_available()
print('Torch device - GPU' if use_cuda else 'Torch device - CPU')
# Out:
# 0.4.1
# Torch device - CPU

# %% [markdown]
# <h3>2. Data loading routines </h3>
# <p> Train and Test loaders are initialized to return shuffled batches of data </p>

# %%
from __future__ import print_function
from observations import multi_mnist
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import torch
import math
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms
from torchvision.utils import save_image
from torch.utils.data import DataLoader
from torch.distributions.bernoulli import Bernoulli
from torch.distributions.normal import Normal

torch.manual_seed(1)
device = torch.device("cuda" if use_cuda else "cpu")

''' Data loading routines '''

def shuffle_data(X, y):
    ''' Random shuffle of the samples in X and y '''
    idx = np.arange(X.shape[0])
    np.random.shuffle(idx)
    return X[idx], y[idx]

def batch_iterator(X, y=None, batch_size=64):
    ''' Simple batch generator '''
    n_samples = X.shape[0]
    for i in np.arange(0, n_samples, batch_size):
        begin, end = i, min(i+batch_size, n_samples)
        if y is not None:
            yield X[begin:end], y[begin:end]
        else:
            yield X[begin:end]
            
def fetch_data():
    ''' Downloads multi_mnist dataset to inpath location 
        Normalizes and shuffles data (70k image-label pairs)
        Train-test split : (60k : 10k) is standard and *cannot* be tuned.
    '''
    inpath = './data/'
    (X_train, y_train), (X_test, y_test) = multi_mnist(inpath, max_digits=2, canvas_size=50, seed=42)
    X_train, X_test = X_train.astype(np.float32), X_test.astype(np.float32)
    X_train /= 255.0
    X_test /= 255.0
    
    X_train, y_train = shuffle_data(X_train, y_train)
    X_test, y_test = shuffle_data(X_test, y_test)

    return torch.from_numpy(X_train), y_train, torch.from_numpy(X_test), y_test

def data_iter_init():
    ''' Returns train_data_loader and test_data_loader '''
    X_train, y_train, X_test, y_test = fetch_data()
    train_dset_size, test_dset_size = X_train.size(0), X_test.size(0)
    return batch_iterator(X_train, y_train), batch_iterator(X_test, y_test), train_dset_size, test_dset_size

# %% [markdown]
# <p><b> Spatial Transformer network </b></p>
# <p> AIR network outputs z_where as [scale, x_coord, y_coord] which encodes the pose information. This latent code is used (1) to extract an object from image, and (2) to align an object while reconstructing the full image</p>

# %%
''' Spatial Transformer Network operations
    Taken from Pyro implementation : http://pyro.ai/examples/air.html
'''

def expand_z_where(z_where):
    ''' Takes 3-dimensional vectors, and massages them into 2x3 matrices with elements like so:
        [s,x,y] -> [[s,0,x],
                    [0,s,y]]
    '''
    n = z_where.size(0)
    expansion_indices = torch.LongTensor([1, 0, 2, 0, 1, 3]).to(device)
    out = torch.cat((torch.zeros([1, 1]).expand(n, 1).to(device), z_where), 1)
    return torch.index_select(out, 1, expansion_indices).view(n, 2, 3)

def object_to_image(z_where, obj):
    ''' obj of dimension 20x20 is laid on a 50x50 canvas, and aligned & scaled based on z_where '''
    n = obj.size(0)
    theta = expand_z_where(z_where)
    grid = F.affine_grid(theta, torch.Size((n, 1, 50, 50)))
    out = F.grid_sample(obj.view(n, 1, 20, 20), grid)
    return out.view(n, 50, 50)


def z_where_inv(z_where):
    ''' Take a batch of z_where vectors, and compute their "inverse".
        That is, for each row compute:
        [s,x,y] -> [1/s,-x/s,-y/s]
        These are the parameters required to perform the inverse of the
        spatial transform performed in the generative model.
    '''
    n = z_where.size(0)
    out = torch.cat((torch.ones([1, 1]).type_as(z_where).expand(n, 1).to(device), -z_where[:, 1:]), 1)
    out = out / z_where[:, 0:1]
    return out

def image_to_object(z_where, image):
    ''' obj of dimension 20x20 is extracted from image of 50x50 using z_where '''
    n = image.size(0)
    theta_inv = expand_z_where(z_where_inv(z_where))
    grid = F.affine_grid(theta_inv, torch.Size((n, 1, 20, 20)))
    out = F.grid_sample(image.view(n, 1, 50, 50), grid)
    return out.view(n, -1)

# %% [markdown]
# <h3>3. Class describing state of latent variables</h3>
# <p> Z_pres alone is initialized to all ones </p>
# <p> Z_where and Z_what are intitalized to zeros </p>
# <p> These init values are passed as input to the inference network (LSTM) in its very first step </p>

# %%
class latent_code_state(object):
    
    def __init__(self, batch_size, z_pres_dim, z_where_dim, z_what_dim, lstm_state_dim):
        self.z_where_scale_mu = None
        self.z_where_scale_logvar = None
        self.z_where_shift_mu = None
        self.z_where_shift_logvar = None
        self.z_where = torch.zeros(batch_size, z_where_dim).to(device)
        self.z_what_mu = None
        self.z_what_logvar = None
        self.z_what = torch.zeros(batch_size, z_what_dim).to(device)
        self.z_pres_prob = 0.01 * torch.ones(batch_size)
        self.z_pres = torch.ones(batch_size, z_pres_dim).to(device)
        self.h = torch.zeros(batch_size, lstm_state_dim).to(device)
        self.c = torch.zeros(batch_size, lstm_state_dim).to(device)
        self.baseline_z_pres = torch.ones(batch_size, z_pres_dim).to(device)
        self.baseline_h = torch.zeros(batch_size, lstm_state_dim).to(device)
        self.baseline_c = torch.zeros(batch_size, lstm_state_dim).to(device)
        self.z_pres_list = []

# %%
def log_standard_gaussian(x):
    ''' Evaluates the log pdf of a standard normal distribution at x.
        :param x: point to evaluate
        :return: log N(x|0,I)
    '''
    return torch.sum(-0.5 * math.log(2 * math.pi) - x ** 2 / 2, dim=-1)


def log_gaussian(x, mu, log_var):
    ''' Returns the log pdf of a normal distribution parametrised
        by mu and log_var evaluated at x.
        :param x: point to evaluate
        :param mu: mean of distribution
        :param log_var: log variance of distribution
        :return: log N(x|µ,σ)
    '''
    log_pdf = - 0.5 * math.log(2 * math.pi) - log_var / 2 - (x - mu)**2 / (2 * torch.exp(log_var))
    return torch.sum(log_pdf, dim=-1)

def compute_kld(z, q_mu, q_logvar):
    ''' Computes the KL-divergence of
        some element z.
        KL(q||p) = -∫ q(z) log [ p(z) / q(z) ]
                 = -E[log p(z) - log q(z)]
        :param z: sample from q-distribuion
        :param q_param: (mu, log_var) of the q-distribution
        :param p_param: (mu, log_var) of the p-distribution : Assumed to be  (0,1)
        :return: KL(q||p)
    '''

    qz = log_gaussian(z, q_mu, q_logvar)
    pz = log_standard_gaussian(z)
    
    kl = qz - pz

    return kl

# %%
z_pres_prior_prob_init = 0.01
# Defines something like a truncated geometric. Like the geometric,
# this has the property that there's a constant difference in log prob
# between p(steps=n) and p(steps=n+1).
class bernoulli_to_geom_prior():
    def __init__(self, prior_prob):
        self.prior_prob = prior_prob
        
    def make_prior(self, k):
        assert 0 < k <= 1
        u = 1 / (1 + k + k**2 + k**3)
        p0 = 1 - u
        p1 = 1 - (k * u) / p0
        p2 = 1 - (k**2 * u) / (p0 * p1)
        trial_probs = [p0, p1, p2]
        dist = [1 - p0, p0 * (1 - p1), p0 * p1 * (1 - p2), p0 * p1 * p2]
        # print(dist)
        return lambda t: [trial_probs[i] for i in t]

    def log_prob(self, n_steps):
        self.joint = self.make_prior(self.prior_prob)
        probs = torch.Tensor(self.joint(n_steps.int()))
        return probs.log()

# %% [markdown]
# <h3>4. AIR module</h3>
# <p> The model is split into an infer net and a generator net. Infer net spits out z_pres, z_where and z_what from image and previous state information, while the Generator net reconstructs entire image from z_pres, z_where and z_what codes. N = 3 time steps are executed with the (infer net - generator net) combo. </p>

# %%
class AIR(nn.Module):
    def __init__(self):
        super(AIR, self).__init__()
        self.inp_dim = 2500
        self.obj_dim = 400
        self.obj_hidden_dim = 200
        self.z_where_dim = 3
        self.z_what_dim = 50
        self.z_pres_dim = 1
        self.lstm_state_dim = 256
        
        self.rnn = nn.LSTMCell(self.inp_dim + self.z_what_dim + self.z_where_dim + self.z_pres_dim,
                               self.lstm_state_dim)
        
        self.baseline_rnn = nn.LSTMCell(self.inp_dim + self.z_what_dim + self.z_where_dim + self.z_pres_dim,
                                        self.lstm_state_dim)
        
        self.baseline_predict = nn.Linear(self.lstm_state_dim, self.z_pres_dim)
        
        ''' Predict z_pres and z_where (mu, logvar) from lstm hidden state information '''
        self.latent_pred = nn.Linear(self.lstm_state_dim,
                                     self.z_pres_dim + self.z_where_dim + self.z_where_dim)
        
        ''' Encoder layers: Encode object under attention window, into z_what (mu, logvar) '''
        self.fc1 = nn.Linear(self.obj_dim, self.obj_hidden_dim)
        self.fc2 = nn.Linear(self.obj_hidden_dim, 2 * self.z_what_dim)
        
        ''' Decoder layers: Decode z_what (mu, logvar) into corresponding object '''
        self.fc3 = nn.Linear(self.z_what_dim, self.obj_hidden_dim)
        self.fc4 = nn.Linear(self.obj_hidden_dim, self.obj_dim)
    
    

    def baseline_estimate(self, x, prev):
        rnn_input = torch.cat((x,
                               prev.z_where.detach(),
                               prev.z_what.detach(),
                               prev.z_pres.detach()), 1)
        
        baseline_h, baseline_c = self.baseline_rnn(rnn_input, (prev.baseline_h, prev.baseline_c))
        baseline_z_pres_prob = self.baseline_predict(baseline_h) * prev.z_pres
        prev.baseline_z_pres_prob = baseline_z_pres_prob
        return baseline_z_pres_prob, baseline_h, baseline_c
    
    def vimco_grad_estimate(self, x, prev, k):
        
        batch_size = x.size(0)
        baseline_values = []
        baseline_logprobs = []
        posterior_logprobs = []
        joint_prior = bernoulli_to_geom_prior(z_pres_prior_prob_init)
        
        for i in range(k):
            
            val = self.baseline_estimate(x, prev)
            prev.baseline_h = val[1]
            prev.baseline_c = val[2] 
            
            
            z_pres_prob = F.sigmoid(val[0])
            z_pres_distrib = Bernoulli(z_pres_prob * prev.z_pres)
            z_pres = z_pres_distrib.sample()
            z_pres_logprob = z_pres_distrib.log_prob(z_pres)
            joint_logprob = joint_prior.log_prob(z_pres)
            
            prev.z_pres = z_pres
            baseline_values.append(z_pres_prob)
            baseline_logprobs.append(joint_logprob)
            posterior_logprobs.append(z_pres_logprob)

        k_sample_logprob = torch.Tensor([[baseline_logprobs[i][j] for i in range(k)] for j in range(batch_size)])
        
        
        # Multi-sample stochastic bound
        L_hat = k_sample_logprob.logsumexp(1) - math.log(k)
        
        # Σ log_probs
        s = k_sample_logprob.sum(1)
        
        L_hat_neg = torch.zeros_like(k_sample_logprob)
        
        for i in range(k):
            
            save_log_prob = k_sample_logprob[:, i]
            k_sample_logprob[:, i] = (s - k_sample_logprob[:, i]) / (k - 1)
            L_hat_neg[:, i] = k_sample_logprob.logsumexp(1) - math.log(k)
            k_sample_logprob[:, i] = save_log_prob
            
        # Importance weights
        w = F.softmax(k_sample_logprob, 1)
        
        vimco_loss = 0
        for i in range(k):
            vimco_loss += (L_hat - L_hat_neg[:, i]) * posterior_logprobs[i].squeeze()
            vimco_loss += w[:, i] * k_sample_logprob[:, i]

        return vimco_loss, baseline_values  
        
    
    def infer_net(self, x, prev):
        
        ''' Pass [previous z_code (pres + where+ what) + input image] to LSTM '''
        rnn_ip = torch.cat((x,
                            prev.z_where,
                            prev.z_what,
                            prev.z_pres), 1)
        
        h, c = self.rnn(rnn_ip, (prev.h, prev.c))
        
        ''' Fetch z_pres + z_where (mu, logvar) '''
        z_code = self.latent_pred(h)
        
        ''' z_pres probability is multiplied with previous z_pres,
            so as to force current z_pres to 0, if previous z_pres
            was 0 as well. This way we ensure that if z_pres is 0
            at any time step, all further time steps give z_pres=0.
        '''
        # z_pres_prob = F.sigmoid(z_code[:, 0:1]) - baseline_z_pres_prob.detach()
        # z_pres = Bernoulli(z_pres_prob.clamp(min=0., max=1.) * prev.z_pres).sample()
        z_pres_prob = F.sigmoid(z_code[:, 0:1])
        z_pres_distrib = Bernoulli(z_pres_prob * prev.z_pres)
        z_pres = z_pres_distrib.sample()
        z_pres_distrib.log_prob(z_pres)
        
        ''' z_where parameters are continuous latent variables on which
            we apply reparameterization trick for approximate variational inference
        '''
        z_where_mu = z_code[:, 1:4]
        z_where_logvar = z_code[:, 4:]
        z_where = self.reparameterize(z_where_mu, z_where_logvar)
        
        ''' Spatial transformer nets are used to generate attention window for object
            located by z_where, from original image 'x' 
        '''
        x_att = image_to_object(z_where, x)   
        
        ''' Encode object to its z-what params (mu, logvar), followed by reparameterizing
        '''
        h_enc = F.relu(self.fc1(x_att))
        z_what_code = self.fc2(h_enc)
        
        
        ''' Store all state information for next time step of AIR network
        '''
        prev.z_what_mu = z_what_code[:, :50]
        prev.z_what_logvar = z_what_code[:, 50:]
        prev.z_what = self.reparameterize(z_what_code[:, :50], z_what_code[:, 50:])
        
        prev.z_where_mu = z_where_mu
        prev.z_where_logvar = z_where_logvar
        prev.z_where = z_where
        
        prev.z_pres_prob = z_pres_prob
        prev.z_pres = z_pres
        prev.z_pres_list.append({'z_pres_prob':[round(i.item(), 2) for i in z_pres_prob],\
                                 'z_pres':[round(i.item(), 2) for i in z_pres]})
        prev.h = h
        prev.c = c
        
        return prev


    def reparameterize(self, mu, logvar):
        if self.training:
            std = torch.exp(0.5*logvar)
            eps = torch.randn_like(std)
            return eps.mul(std).add_(mu)
        else:
            return mu
    
    def generator_net(self, recon_x, curr):
        
        ''' Reconstruct object from z_what '''
        h_dec = F.relu(self.fc3(curr.z_what))
        y_att = F.sigmoid(self.fc4(h_dec))
        
        ''' Spatial Transformer to align and scale reconstructed object into an image canvas '''
        y = object_to_image(curr.z_where, y_att).view(-1, 2500)
        
        ''' Reconstruct full image by summing up 'y' based on predicted z_pres(0/1) '''
        recon_x = recon_x + y * curr.z_pres.view(-1, 1)
        
        return recon_x

    def forward(self, x):
        
        N = 3
        score_function_loss = 0
        code = latent_code_state(x.size(0), self.z_pres_dim, self.z_where_dim,
                                 self.z_what_dim, self.lstm_state_dim)
        recon_x = torch.zeros_like(x.view(-1, 2500))
        
        for i in range(N):
            
            loss, baseline_values = self.vimco_grad_estimate(x.view(-1, 2500), code, k=10)
            score_function_loss += loss
            
            code = self.infer_net(x.view(-1, 2500), code)
            
            recon_x = self.generator_net(recon_x, code).view(-1, 2500)
            
        
        ''' After all N steps, fetch latent variable params + samples to compute kl divergence '''
        ''' **TODO**  : Add the contribution of z_pres : Bernoulli_to_modified_geometric_distribution '''
        kld_loss = compute_kld(code.z_what, code.z_what_mu, code.z_what_logvar) + \
                   compute_kld(code.z_where, code.z_where_mu, code.z_where_logvar)

        # baseline_net_loss = F.mse_loss(code.baseline_z_pres_prob, code.z_pres_prob)
        baseline_net_loss = 0
        
        return recon_x, code, kld_loss, baseline_net_loss, score_function_loss

    def generate_sample(self, x):
        ''' Called during testing phase to sample reconstructions from prior codes.
            Not to be called while training
        '''
        N = 3
        code = latent_code_state(x.size(0), self.z_pres_dim, self.z_where_dim,
                                 self.z_what_dim, self.lstm_state_dim)
        recon_x = torch.zeros_like(x.view(-1, 2500))
        recon_stages = torch.zeros(N, recon_x.size(0), 2500)
        
        for i in range(N):
            
            code = self.infer_net(x.view(-1, 2500), code)
            recon_x = self.generator_net(recon_x, code).view(-1, 2500)
            recon_stages[i] = recon_x
        
        [print(i) for i in code.z_pres_list]
        return recon_stages
    

model = AIR().to(device)
#model.state_dict = torch.load('air_0.pt')
optimizer = optim.Adam(model.parameters(), lr=1e-3)


# Reconstruction loss
def loss_function(recon_x, x):
    ''' Estimate quality of reconstructions with BCE '''
    BCE = F.binary_cross_entropy(recon_x.clamp(min=0., max=1.), x.view(-1, 2500), size_average=False)
    return BCE

def train(epoch, train_iter, train_dset_size):
    
    model.train()
    log_interval = 10
    train_loss = 0
    
    for batch_idx, (data, _) in enumerate(train_iter):
        data = data.to(device)
        optimizer.zero_grad()
        batch_loss = 0
        
        x = data.view(-1, 2500)
        recon_x, code, kld, baseline_loss, score_function_loss = model(x)
        batch_loss = loss_function(recon_x, x) + kld.sum() + score_function_loss.sum() # + baseline_loss.sum()

        batch_loss.backward()
        train_loss += batch_loss.item()
        optimizer.step()
        
        
        '''
        **LABEL** : COMMENTED OUT LOG OUTPUT INFORMATION (ENABLE AS AND WHEN NEEDED)
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), train_dset_size,
                100. * batch_idx / (train_dset_size//batch_size),
                batch_loss.item() / len(data)))
        '''
    print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, train_loss / train_dset_size))


def test(epoch, test_iter, test_dset_size):
    model.eval()
    test_loss = 0
    
    with torch.no_grad():
        for i, (data, _) in enumerate(test_iter):
            data = data.to(device)
            
            batch_loss = 0
            x = data.view(-1, 2500)
            recon_x, code, kld, baseline_loss, score_func_loss = model(x)
            
            batch_loss = loss_function(recon_x, x).item() + \
                         kld.sum().item() + \
                         score_func_loss.sum().item() # + baseline_loss.sum().item()
                
            test_loss += batch_loss
            
            ''' Plot images as :
            
                Img1        Img2        Img3        Img4
                Recon1_t=0  Recon2_t=0  Recon3_t=0  Recon4_t=0
                Recon1_t=1  Recon2_t=1  Recon3_t=1  Recon4_t=1
                Recon1_t=2  Recon2_t=2  Recon3_t=2  Recon4_t=2
            '''
            if i == 0:
                n = min(data.size(0), 4)
                N = 3

                x = data[:n].view(-1, 2500)
                recon_x = model.generate_sample(x)
                recon_batch = recon_x.view(N, n, 1, 2500)
                
                comparison = torch.cat([data[:n].view(-1, 1, 50, 50),
                                        recon_batch[0].view(-1, 1, 50, 50),
                                        recon_batch[1].view(-1, 1, 50, 50),
                                        recon_batch[2].view(-1, 1, 50, 50)])
                
                save_image(comparison.cpu(),
                           'reconstruction_' + str(epoch) + '.png', nrow=n)

                img = mpimg.imread('reconstruction_' + str(epoch) + '.png')
                plt.axis('off')
                plt.title('reconstruction_' + str(epoch) + '.png')
                plt.imshow(img)
                plt.show()

    test_loss /= test_dset_size
    print('====> Test set loss: {:.4f}'.format(test_loss))

epochs = 25
for epoch in range(1, epochs + 1):
    train_iter, test_iter, train_dset_size, test_dset_size = data_iter_init()
    train(epoch, train_iter, train_dset_size)
    test(epoch, test_iter, test_dset_size)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\torch\nn\functional.py:1006: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# C:\Program Files\Anaconda3\lib\site-packages\torch\nn\functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# ====> Epoch: 1 Average loss: 1554.3668
# {'z_pres_prob': [0.54, 0.51, 0.55, 0.56], 'z_pres': [0.0, 0.0, 0.0, 1.0]}
# {'z_pres_prob': [0.55, 0.51, 0.56, 0.57], 'z_pres': [0.0, 0.0, 0.0, 1.0]}
# {'z_pres_prob': [0.52, 0.51, 0.52, 0.54], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# ====> Test set loss: 1585.8390
# ====> Epoch: 2 Average loss: 1564.4125
# {'z_pres_prob': [0.51, 0.56, 0.51, 0.52], 'z_pres': [1.0, 0.0, 1.0, 0.0]}
# {'z_pres_prob': [0.51, 0.58, 0.51, 0.52], 'z_pres': [1.0, 0.0, 0.0, 0.0]}
# {'z_pres_prob': [0.51, 0.52, 0.51, 0.51], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# ====> Test set loss: 1593.7545
# ====> Epoch: 3 Average loss: 1572.4334
# {'z_pres_prob': [0.57, 0.55, 0.51, 0.51], 'z_pres': [0.0, 0.0, 1.0, 0.0]}
# {'z_pres_prob': [0.57, 0.53, 0.51, 0.51], 'z_pres': [0.0, 0.0, 1.0, 0.0]}
# {'z_pres_prob': [0.51, 0.49, 0.51, 0.51], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# ====> Test set loss: 1606.4838
# ====> Epoch: 4 Average loss: 1574.6701
# {'z_pres_prob': [0.52, 0.53, 0.55, 0.57], 'z_pres': [0.0, 0.0, 1.0, 0.0]}
# {'z_pres_prob': [0.52, 0.56, 0.55, 0.57], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# {'z_pres_prob': [0.51, 0.53, 0.52, 0.51], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# ====> Test set loss: 1606.1652
# ====> Epoch: 5 Average loss: 1575.7592
# {'z_pres_prob': [0.58, 0.54, 0.51, 0.55], 'z_pres': [1.0, 1.0, 1.0, 1.0]}
# {'z_pres_prob': [0.58, 0.56, 0.51, 0.54], 'z_pres': [1.0, 1.0, 1.0, 1.0]}
# {'z_pres_prob': [0.51, 0.52, 0.51, 0.49], 'z_pres': [1.0, 1.0, 1.0, 1.0]}
# ====> Test set loss: 1599.9041
# ====> Epoch: 6 Average loss: 1569.6434
# {'z_pres_prob': [0.54, 0.51, 0.51, 0.56], 'z_pres': [0.0, 1.0, 0.0, 1.0]}
# {'z_pres_prob': [0.53, 0.51, 0.51, 0.56], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# {'z_pres_prob': [0.51, 0.52, 0.51, 0.51], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# ====> Test set loss: 1603.8056
# ====> Epoch: 7 Average loss: 1570.0361
# {'z_pres_prob': [0.56, 0.59, 0.56, 0.55], 'z_pres': [1.0, 1.0, 1.0, 1.0]}
# {'z_pres_prob': [0.52, 0.55, 0.5, 0.53], 'z_pres': [0.0, 0.0, 1.0, 1.0]}
# {'z_pres_prob': [0.51, 0.5, 0.5, 0.5], 'z_pres': [0.0, 0.0, 1.0, 0.0]}
# ====> Test set loss: 1606.4121
# ====> Epoch: 8 Average loss: 1566.0929
# {'z_pres_prob': [0.53, 0.55, 0.59, 0.51], 'z_pres': [0.0, 1.0, 1.0, 1.0]}
# {'z_pres_prob': [0.51, 0.53, 0.52, 0.53], 'z_pres': [0.0, 1.0, 1.0, 1.0]}
# {'z_pres_prob': [0.5, 0.5, 0.5, 0.53], 'z_pres': [0.0, 0.0, 0.0, 1.0]}
# ====> Test set loss: 1593.2586
# ====> Epoch: 9 Average loss: 1572.3534
# {'z_pres_prob': [0.56, 0.59, 0.55, 0.51], 'z_pres': [1.0, 1.0, 1.0, 0.0]}
# {'z_pres_prob': [0.53, 0.59, 0.55, 0.53], 'z_pres': [1.0, 0.0, 1.0, 0.0]}
# {'z_pres_prob': [0.5, 0.5, 0.51, 0.52], 'z_pres': [0.0, 0.0, 1.0, 0.0]}
# ====> Test set loss: 1607.8574
# ====> Epoch: 10 Average loss: 1575.8401
# {'z_pres_prob': [0.58, 0.51, 0.53, 0.51], 'z_pres': [0.0, 0.0, 0.0, 1.0]}
# {'z_pres_prob': [0.52, 0.54, 0.52, 0.54], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# {'z_pres_prob': [0.52, 0.52, 0.5, 0.52], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# ====> Test set loss: 1604.8774
# ====> Epoch: 11 Average loss: 1576.5075
# {'z_pres_prob': [0.5, 0.53, 0.5, 0.54], 'z_pres': [1.0, 0.0, 0.0, 1.0]}
# {'z_pres_prob': [0.55, 0.52, 0.54, 0.53], 'z_pres': [1.0, 0.0, 0.0, 1.0]}
# {'z_pres_prob': [0.52, 0.5, 0.52, 0.5], 'z_pres': [1.0, 0.0, 0.0, 1.0]}
# ====> Test set loss: 1605.7027
# ====> Epoch: 12 Average loss: 1573.6041
# {'z_pres_prob': [0.55, 0.55, 0.54, 0.5], 'z_pres': [0.0, 1.0, 1.0, 1.0]}
# {'z_pres_prob': [0.53, 0.53, 0.53, 0.56], 'z_pres': [0.0, 1.0, 0.0, 0.0]}
# {'z_pres_prob': [0.51, 0.51, 0.51, 0.51], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# ====> Test set loss: 1604.2602
# ====> Epoch: 13 Average loss: 1577.8921
# {'z_pres_prob': [0.54, 0.5, 0.52, 0.5], 'z_pres': [0.0, 0.0, 1.0, 0.0]}
# {'z_pres_prob': [0.51, 0.56, 0.51, 0.56], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# {'z_pres_prob': [0.51, 0.51, 0.5, 0.51], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# ====> Test set loss: 1607.6746
# ====> Epoch: 14 Average loss: 1547.3088
# {'z_pres_prob': [0.52, 0.54, 0.54, 0.56], 'z_pres': [1.0, 1.0, 0.0, 0.0]}
# {'z_pres_prob': [0.51, 0.54, 0.54, 0.55], 'z_pres': [0.0, 1.0, 0.0, 0.0]}
# {'z_pres_prob': [0.5, 0.51, 0.5, 0.5], 'z_pres': [0.0, 1.0, 0.0, 0.0]}
# ====> Test set loss: 1600.2537
# ====> Epoch: 15 Average loss: 1571.7287
# {'z_pres_prob': [0.52, 0.49, 0.56, 0.53], 'z_pres': [0.0, 1.0, 0.0, 0.0]}
# {'z_pres_prob': [0.49, 0.58, 0.56, 0.52], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# {'z_pres_prob': [0.5, 0.51, 0.5, 0.5], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# ====> Test set loss: 1605.3829
# ====> Epoch: 16 Average loss: 1576.2794
# {'z_pres_prob': [0.53, 0.55, 0.52, 0.55], 'z_pres': [0.0, 1.0, 1.0, 0.0]}
# {'z_pres_prob': [0.55, 0.53, 0.54, 0.56], 'z_pres': [0.0, 1.0, 0.0, 0.0]}
# {'z_pres_prob': [0.51, 0.51, 0.5, 0.5], 'z_pres': [0.0, 1.0, 0.0, 0.0]}
# ====> Test set loss: 1605.2750
# ====> Epoch: 17 Average loss: 1575.6249
# {'z_pres_prob': [0.52, 0.53, 0.53, 0.49], 'z_pres': [0.0, 0.0, 0.0, 1.0]}
# {'z_pres_prob': [0.49, 0.51, 0.53, 0.58], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# {'z_pres_prob': [0.5, 0.5, 0.51, 0.51], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# ====> Test set loss: 1606.1570
# ====> Epoch: 18 Average loss: 1559.2848
# {'z_pres_prob': [0.49, 0.55, 0.49, 0.55], 'z_pres': [1.0, 1.0, 1.0, 1.0]}
# {'z_pres_prob': [0.58, 0.51, 0.58, 0.55], 'z_pres': [0.0, 0.0, 1.0, 0.0]}
# {'z_pres_prob': [0.51, 0.5, 0.51, 0.5], 'z_pres': [0.0, 0.0, 1.0, 0.0]}
# ====> Test set loss: 1599.3080
# ====> Epoch: 19 Average loss: 1575.7358
# {'z_pres_prob': [0.56, 0.56, 0.49, 0.55], 'z_pres': [1.0, 1.0, 1.0, 1.0]}
# {'z_pres_prob': [0.57, 0.55, 0.58, 0.54], 'z_pres': [0.0, 0.0, 1.0, 1.0]}
# {'z_pres_prob': [0.51, 0.52, 0.51, 0.5], 'z_pres': [0.0, 0.0, 0.0, 1.0]}
# ====> Test set loss: 1595.7735
# ====> Epoch: 20 Average loss: 1576.2861
# {'z_pres_prob': [0.52, 0.54, 0.58, 0.54], 'z_pres': [0.0, 0.0, 1.0, 0.0]}
# {'z_pres_prob': [0.52, 0.52, 0.57, 0.52], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# {'z_pres_prob': [0.5, 0.5, 0.51, 0.52], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# ====> Test set loss: 1608.1618
# ====> Epoch: 21 Average loss: 1575.4595
# {'z_pres_prob': [0.55, 0.56, 0.53, 0.49], 'z_pres': [1.0, 1.0, 0.0, 0.0]}
# {'z_pres_prob': [0.54, 0.55, 0.53, 0.58], 'z_pres': [1.0, 1.0, 0.0, 0.0]}
# {'z_pres_prob': [0.5, 0.5, 0.51, 0.51], 'z_pres': [0.0, 1.0, 0.0, 0.0]}
# ====> Test set loss: 1582.7461
# ====> Epoch: 22 Average loss: 1571.2500
# {'z_pres_prob': [0.53, 0.49, 0.49, 0.53], 'z_pres': [0.0, 0.0, 1.0, 1.0]}
# {'z_pres_prob': [0.56, 0.58, 0.58, 0.52], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# {'z_pres_prob': [0.5, 0.51, 0.51, 0.5], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# ====> Test set loss: 1589.7189
# ====> Epoch: 23 Average loss: 1574.6415
# {'z_pres_prob': [0.52, 0.53, 0.54, 0.49], 'z_pres': [1.0, 0.0, 1.0, 1.0]}
# {'z_pres_prob': [0.51, 0.54, 0.55, 0.58], 'z_pres': [1.0, 0.0, 1.0, 0.0]}
# {'z_pres_prob': [0.5, 0.51, 0.5, 0.51], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# ====> Test set loss: 1600.8116
# ====> Epoch: 24 Average loss: 1573.5801
# {'z_pres_prob': [0.49, 0.49, 0.56, 0.56], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# {'z_pres_prob': [0.58, 0.58, 0.55, 0.57], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# {'z_pres_prob': [0.51, 0.51, 0.49, 0.5], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# ====> Test set loss: 1604.6428
# ====> Epoch: 25 Average loss: 1571.0148
# {'z_pres_prob': [0.5, 0.52, 0.52, 0.49], 'z_pres': [0.0, 0.0, 1.0, 0.0]}
# {'z_pres_prob': [0.51, 0.55, 0.54, 0.58], 'z_pres': [0.0, 0.0, 1.0, 0.0]}
# {'z_pres_prob': [0.5, 0.5, 0.5, 0.51], 'z_pres': [0.0, 0.0, 0.0, 0.0]}
# ====> Test set loss: 1607.1630

# %%
a = torch.randn((64))
b = torch.randn((64))
(a*b).shape
# Out:
# torch.Size([64])

# %%
def make_prior(k):
    assert 0 < k <= 1
    u = 1 / (1 + k + k**2 + k**3)
    p0 = 1 - u
    p1 = 1 - (k * u) / p0
    p2 = 1 - (k**2 * u) / (p0 * p1)
    trial_probs = [p0, p1, p2]
    # dist = [1 - p0, p0 * (1 - p1), p0 * p1 * (1 - p2), p0 * p1 * p2]
    # print(dist)
    return lambda t: trial_probs[t]

# %%
u = make_prior(0.5)
v = np.random.randint(0, 3, 5)
v = v.reshape(1,-1)
u(v)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-ca9f1df6b216> in <module>()
#       2 v = np.random.randint(0, 3, 5)
#       3 v = v.reshape(1,-1)
# ----> 4 u(v)
#
# <ipython-input-14-5a2e4fa799af> in <lambda>(t)
#       8     # dist = [1 - p0, p0 * (1 - p1), p0 * p1 * (1 - p2), p0 * p1 * p2]
#       9     # print(dist)
# ---> 10     return lambda t: trial_probs[t]
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
a = torch.randn((2,4))
a, F.softmax(a, 0), F.softmax(a, 1)
# Out:
# (tensor([[-0.9035, -1.2258,  0.4900, -0.8620],
#          [-0.6165, -0.8566,  1.0620, -1.4890]]),
#  tensor([[0.4288, 0.4087, 0.3608, 0.6518],
#          [0.5712, 0.5913, 0.6392, 0.3482]]),
#  tensor([[0.1472, 0.1066, 0.5928, 0.1534],
#          [0.1322, 0.1040, 0.7085, 0.0553]]))

# %%
a[0][0], a[1][0]
# Out:
# (tensor(-0.9035), tensor(-0.6165))

# %%
c,d = a[0][0].exp(), a[1][0].exp()

# %%
c/(c+d)
# Out:
# tensor(0.4288)

# %%
t = [[a[i][j] for i in range(10)] for j in range(64)]
t
# Out:
# [[tensor(-0.4825),
#   tensor(1.4369),
#   tensor(-0.3659),
#   tensor(-1.1050),
#   tensor(0.2870),
#   tensor(0.0425),
#   tensor(0.3296),
#   tensor(1.3992),
#   tensor(0.2363),
#   tensor(0.8721)],
#  [tensor(2.4895),
#   tensor(1.6232),
#   tensor(-2.1264),
#   tensor(2.4330),
#   tensor(-0.7498),
#   tensor(-1.6346),
#   tensor(-0.4926),
#   tensor(-1.6107),
#   tensor(-1.0476),
#   tensor(0.1000)],
#  [tensor(0.1868),
#   tensor(1.4430),
#   tensor(-0.1116),
#   tensor(0.3754),
#   tensor(-0.7784),
#   tensor(0.2192),
#   tensor(1.0814),
#   tensor(0.4421),
#   tensor(-1.0631),
#   tensor(-0.8104)],
#  [tensor(-0.3400),
#   tensor(2.1045),
#   tensor(-0.7199),
#   tensor(0.7206),
#   tensor(-0.1784),
#   tensor(0.4224),
#   tensor(-0.8189),
#   tensor(-0.7139),
#   tensor(-0.2931),
#   tensor(-1.2962)],
#  [tensor(1.4749),
#   tensor(0.1863),
#   tensor(-0.1276),
#   tensor(-0.9629),
#   tensor(-1.7404),
#   tensor(0.8733),
#   tensor(0.1453),
#   tensor(0.8213),
#   tensor(-0.9372),
#   tensor(0.4840)],
#  [tensor(-0.8733),
#   tensor(0.5962),
#   tensor(-0.5274),
#   tensor(1.1951),
#   tensor(0.1385),
#   tensor(-0.1991),
#   tensor(-1.3049),
#   tensor(-0.2926),
#   tensor(-0.4359),
#   tensor(1.8747)],
#  [tensor(-1.6606),
#   tensor(0.4522),
#   tensor(-0.4660),
#   tensor(-0.8880),
#   tensor(-1.1498),
#   tensor(2.0131),
#   tensor(-1.4472),
#   tensor(-0.3012),
#   tensor(-1.8628),
#   tensor(-0.7050)],
#  [tensor(-0.6250),
#   tensor(1.0766),
#   tensor(1.3329),
#   tensor(-0.0731),
#   tensor(1.4502),
#   tensor(0.3205),
#   tensor(1.7647),
#   tensor(-0.3609),
#   tensor(-1.2064),
#   tensor(-0.3995)],
#  [tensor(0.4397),
#   tensor(-0.7252),
#   tensor(2.4192),
#   tensor(-0.1679),
#   tensor(-1.4952),
#   tensor(-1.0575),
#   tensor(-0.1932),
#   tensor(1.5548),
#   tensor(0.9953),
#   tensor(-0.5083)],
#  [tensor(0.5244),
#   tensor(0.0564),
#   tensor(0.1361),
#   tensor(1.1953),
#   tensor(-0.7891),
#   tensor(0.3264),
#   tensor(0.9915),
#   tensor(0.6775),
#   tensor(0.8612),
#   tensor(0.0573)],
#  [tensor(-0.4976),
#   tensor(-0.9084),
#   tensor(0.4869),
#   tensor(0.0639),
#   tensor(-0.2384),
#   tensor(-0.7065),
#   tensor(1.3082),
#   tensor(-0.0242),
#   tensor(-0.2340),
#   tensor(0.0290)],
#  [tensor(1.0539),
#   tensor(-0.3595),
#   tensor(-1.1181),
#   tensor(-1.7610),
#   tensor(0.5798),
#   tensor(-0.1408),
#   tensor(0.0048),
#   tensor(0.9708),
#   tensor(0.5788),
#   tensor(0.7891)],
#  [tensor(0.3110),
#   tensor(-0.1939),
#   tensor(1.9370),
#   tensor(0.8127),
#   tensor(-0.5436),
#   tensor(0.3799),
#   tensor(0.9203),
#   tensor(1.0852),
#   tensor(0.2586),
#   tensor(0.4241)],
#  [tensor(-1.3516),
#   tensor(0.3069),
#   tensor(0.8020),
#   tensor(2.0742),
#   tensor(-0.5272),
#   tensor(-1.2037),
#   tensor(-0.8621),
#   tensor(0.5438),
#   tensor(-1.4878),
#   tensor(0.4068)],
#  [tensor(0.6474),
#   tensor(-0.1911),
#   tensor(1.3547),
#   tensor(-1.5824),
#   tensor(-1.8622),
#   tensor(0.6444),
#   tensor(-0.4307),
#   tensor(0.7648),
#   tensor(1.2653),
#   tensor(-0.2234)],
#  [tensor(0.8936),
#   tensor(0.5909),
#   tensor(0.2012),
#   tensor(-1.4013),
#   tensor(0.2538),
#   tensor(-0.3688),
#   tensor(-1.6892),
#   tensor(-0.3674),
#   tensor(0.4858),
#   tensor(-0.5598)],
#  [tensor(-0.7166),
#   tensor(-0.1594),
#   tensor(-0.2704),
#   tensor(0.7812),
#   tensor(0.3478),
#   tensor(-0.3082),
#   tensor(0.3095),
#   tensor(-1.2955),
#   tensor(0.1494),
#   tensor(-0.8322)],
#  [tensor(0.9896),
#   tensor(-0.1395),
#   tensor(0.6003),
#   tensor(-0.2416),
#   tensor(0.3346),
#   tensor(-0.1917),
#   tensor(0.4958),
#   tensor(0.7383),
#   tensor(-1.0551),
#   tensor(-1.8107)],
#  [tensor(-1.0928),
#   tensor(0.4668),
#   tensor(1.7806),
#   tensor(-0.2978),
#   tensor(-0.0886),
#   tensor(-0.9532),
#   tensor(-0.6328),
#   tensor(1.8091),
#   tensor(-0.3115),
#   tensor(1.0407)],
#  [tensor(1.9672),
#   tensor(0.8934),
#   tensor(-0.6291),
#   tensor(-0.6168),
#   tensor(1.6967),
#   tensor(0.4704),
#   tensor(0.5086),
#   tensor(-0.9635),
#   tensor(-0.8150),
#   tensor(2.4815)],
#  [tensor(1.2015),
#   tensor(0.8565),
#   tensor(-0.7799),
#   tensor(0.8945),
#   tensor(0.1090),
#   tensor(0.3257),
#   tensor(-0.6045),
#   tensor(-0.6024),
#   tensor(-1.9932),
#   tensor(-1.5076)],
#  [tensor(-1.0657),
#   tensor(-0.7377),
#   tensor(-0.9744),
#   tensor(0.0166),
#   tensor(-1.8206),
#   tensor(-0.3359),
#   tensor(2.1581),
#   tensor(0.1998),
#   tensor(0.9650),
#   tensor(-2.0602)],
#  [tensor(-0.6052),
#   tensor(0.9275),
#   tensor(0.6744),
#   tensor(-1.9132),
#   tensor(-2.4132),
#   tensor(1.6785),
#   tensor(-0.8042),
#   tensor(0.9909),
#   tensor(-0.3041),
#   tensor(1.9113)],
#  [tensor(1.9592),
#   tensor(0.4644),
#   tensor(-1.6620),
#   tensor(1.5033),
#   tensor(-0.5806),
#   tensor(1.5404),
#   tensor(0.0110),
#   tensor(0.5248),
#   tensor(-0.3245),
#   tensor(0.5877)],
#  [tensor(0.1956),
#   tensor(0.3995),
#   tensor(0.7069),
#   tensor(1.7611),
#   tensor(-0.3714),
#   tensor(0.9152),
#   tensor(0.4015),
#   tensor(-0.0627),
#   tensor(0.9371),
#   tensor(-0.4471)],
#  [tensor(-0.2133),
#   tensor(0.9850),
#   tensor(0.2454),
#   tensor(1.2619),
#   tensor(1.2933),
#   tensor(-1.2651),
#   tensor(-1.0584),
#   tensor(-2.8672),
#   tensor(-0.7804),
#   tensor(-0.2275)],
#  [tensor(0.3905),
#   tensor(1.8873),
#   tensor(0.9989),
#   tensor(1.6898),
#   tensor(0.5301),
#   tensor(0.3922),
#   tensor(-1.5308),
#   tensor(0.5142),
#   tensor(1.1453),
#   tensor(0.2365)],
#  [tensor(0.8615),
#   tensor(1.8948),
#   tensor(-0.5586),
#   tensor(-0.8729),
#   tensor(0.7788),
#   tensor(0.0166),
#   tensor(-0.6165),
#   tensor(-0.0413),
#   tensor(-0.6077),
#   tensor(1.2396)],
#  [tensor(2.3578),
#   tensor(-0.4137),
#   tensor(-0.5468),
#   tensor(-1.4498),
#   tensor(-1.3621),
#   tensor(0.1197),
#   tensor(0.6636),
#   tensor(0.8303),
#   tensor(0.0281),
#   tensor(0.3175)],
#  [tensor(0.2306),
#   tensor(0.5705),
#   tensor(-0.8032),
#   tensor(-0.2771),
#   tensor(0.3557),
#   tensor(0.0865),
#   tensor(0.1748),
#   tensor(-0.0833),
#   tensor(-0.5810),
#   tensor(-0.6846)],
#  [tensor(1.5838),
#   tensor(-0.6759),
#   tensor(0.1059),
#   tensor(0.1534),
#   tensor(1.0347),
#   tensor(-0.0902),
#   tensor(2.2919),
#   tensor(-0.2410),
#   tensor(0.3701),
#   tensor(0.2968)],
#  [tensor(-1.8232),
#   tensor(-0.4166),
#   tensor(0.3892),
#   tensor(-1.5107),
#   tensor(-1.6600),
#   tensor(0.5938),
#   tensor(-0.4420),
#   tensor(1.8355),
#   tensor(-1.0369),
#   tensor(-0.0914)],
#  [tensor(0.2413),
#   tensor(-0.3852),
#   tensor(1.8006),
#   tensor(0.1446),
#   tensor(0.6890),
#   tensor(0.4717),
#   tensor(-0.5420),
#   tensor(0.9495),
#   tensor(0.0859),
#   tensor(-0.3595)],
#  [tensor(0.0926),
#   tensor(0.0019),
#   tensor(1.3818),
#   tensor(0.1672),
#   tensor(-0.9159),
#   tensor(0.1861),
#   tensor(0.4965),
#   tensor(-1.0769),
#   tensor(1.0644),
#   tensor(-0.1719)],
#  [tensor(-0.1223),
#   tensor(-0.9945),
#   tensor(-0.5911),
#   tensor(0.0984),
#   tensor(1.0492),
#   tensor(-1.4983),
#   tensor(1.4474),
#   tensor(1.6876),
#   tensor(0.9510),
#   tensor(0.8024)],
#  [tensor(-0.8443),
#   tensor(-0.8854),
#   tensor(-1.4114),
#   tensor(0.2725),
#   tensor(0.3571),
#   tensor(-0.7005),
#   tensor(1.1446),
#   tensor(0.0625),
#   tensor(-0.5424),
#   tensor(-0.6302)],
#  [tensor(0.5591),
#   tensor(0.6186),
#   tensor(-0.1958),
#   tensor(-0.8994),
#   tensor(1.5821),
#   tensor(-0.3389),
#   tensor(1.8767),
#   tensor(1.6493),
#   tensor(1.5107),
#   tensor(-0.5934)],
#  [tensor(-1.2825),
#   tensor(-0.7538),
#   tensor(1.2568),
#   tensor(1.2562),
#   tensor(1.1210),
#   tensor(0.9360),
#   tensor(-2.2923),
#   tensor(-0.2715),
#   tensor(1.2540),
#   tensor(-1.1348)],
#  [tensor(0.8915),
#   tensor(-0.6797),
#   tensor(-1.0787),
#   tensor(0.1660),
#   tensor(0.6527),
#   tensor(0.3279),
#   tensor(2.1740),
#   tensor(-1.8916),
#   tensor(0.6320),
#   tensor(0.3000)],
#  [tensor(-0.9292),
#   tensor(-0.1175),
#   tensor(0.5489),
#   tensor(-2.2890),
#   tensor(-0.6822),
#   tensor(-0.0613),
#   tensor(0.0304),
#   tensor(-0.2783),
#   tensor(-0.3228),
#   tensor(-0.2176)],
#  [tensor(-1.5772),
#   tensor(0.0711),
#   tensor(-1.0731),
#   tensor(-0.2757),
#   tensor(1.1561),
#   tensor(-1.0312),
#   tensor(-0.1558),
#   tensor(-0.0012),
#   tensor(-1.3864),
#   tensor(0.8204)],
#  [tensor(1.5751),
#   tensor(0.1220),
#   tensor(-0.6641),
#   tensor(1.5080),
#   tensor(0.7882),
#   tensor(1.5137),
#   tensor(-1.1195),
#   tensor(0.1822),
#   tensor(-0.5429),
#   tensor(0.1512)],
#  [tensor(0.3273),
#   tensor(0.9982),
#   tensor(-0.3681),
#   tensor(-0.8012),
#   tensor(-0.6662),
#   tensor(-0.3790),
#   tensor(-0.2010),
#   tensor(1.2262),
#   tensor(1.2050),
#   tensor(1.5141)],
#  [tensor(0.6435),
#   tensor(-1.7162),
#   tensor(0.5529),
#   tensor(0.2640),
#   tensor(1.2186),
#   tensor(2.5267),
#   tensor(0.3875),
#   tensor(-0.1015),
#   tensor(-0.9733),
#   tensor(0.0501)],
#  [tensor(0.0323),
#   tensor(1.4287),
#   tensor(0.0066),
#   tensor(0.3203),
#   tensor(-0.4888),
#   tensor(-3.0895),
#   tensor(-1.3955),
#   tensor(0.3829),
#   tensor(0.5154),
#   tensor(1.2168)],
#  [tensor(0.8554),
#   tensor(-1.0844),
#   tensor(-2.0299),
#   tensor(0.9561),
#   tensor(-0.2456),
#   tensor(0.2151),
#   tensor(-1.2673),
#   tensor(1.0128),
#   tensor(0.1405),
#   tensor(1.5293)],
#  [tensor(1.7695),
#   tensor(0.1712),
#   tensor(0.5590),
#   tensor(0.7351),
#   tensor(0.0017),
#   tensor(0.8728),
#   tensor(0.6201),
#   tensor(-0.6484),
#   tensor(0.5091),
#   tensor(0.0978)],
#  [tensor(0.1381),
#   tensor(-0.7306),
#   tensor(1.4172),
#   tensor(-0.4781),
#   tensor(0.9720),
#   tensor(0.0511),
#   tensor(-0.4312),
#   tensor(-1.5503),
#   tensor(0.0182),
#   tensor(0.8246)],
#  [tensor(0.5394),
#   tensor(-0.4135),
#   tensor(1.4046),
#   tensor(1.0594),
#   tensor(-1.1620),
#   tensor(-0.4289),
#   tensor(-1.0487),
#   tensor(-0.4196),
#   tensor(-1.0891),
#   tensor(-1.3981)],
#  [tensor(-0.8951),
#   tensor(0.5535),
#   tensor(-0.2161),
#   tensor(0.2331),
#   tensor(0.0736),
#   tensor(0.2570),
#   tensor(-0.7030),
#   tensor(0.7397),
#   tensor(-0.0967),
#   tensor(0.1679)],
#  [tensor(1.4777),
#   tensor(-1.0067),
#   tensor(1.1837),
#   tensor(0.0713),
#   tensor(0.7539),
#   tensor(-0.4393),
#   tensor(0.1042),
#   tensor(0.4214),
#   tensor(-0.4419),
#   tensor(0.8954)],
#  [tensor(0.6707),
#   tensor(1.6460),
#   tensor(0.6832),
#   tensor(-1.3303),
#   tensor(0.7416),
#   tensor(2.4061),
#   tensor(1.3132),
#   tensor(0.4989),
#   tensor(0.7026),
#   tensor(0.6392)],
#  [tensor(-1.4706),
#   tensor(0.7762),
#   tensor(0.5502),
#   tensor(0.7645),
#   tensor(0.0210),
#   tensor(0.3664),
#   tensor(-0.8208),
#   tensor(-1.6893),
#   tensor(-0.6217),
#   tensor(-1.3408)],
#  [tensor(0.1517),
#   tensor(1.1425),
#   tensor(1.3447),
#   tensor(-0.8656),
#   tensor(0.6554),
#   tensor(0.5321),
#   tensor(0.2841),
#   tensor(-1.3804),
#   tensor(-0.0752),
#   tensor(0.0284)],
#  [tensor(-0.7286),
#   tensor(-0.5103),
#   tensor(-0.5083),
#   tensor(-1.8591),
#   tensor(-0.5256),
#   tensor(0.6189),
#   tensor(0.9615),
#   tensor(1.5901),
#   tensor(-1.1828),
#   tensor(-1.2250)],
#  [tensor(0.9210),
#   tensor(0.2401),
#   tensor(0.0671),
#   tensor(1.2947),
#   tensor(-1.0308),
#   tensor(-0.7212),
#   tensor(-1.1722),
#   tensor(0.6536),
#   tensor(1.3107),
#   tensor(-0.1215)],
#  [tensor(-0.5989),
#   tensor(1.9892),
#   tensor(0.1982),
#   tensor(1.3645),
#   tensor(-1.4488),
#   tensor(-1.7538),
#   tensor(1.6739),
#   tensor(1.8983),
#   tensor(-0.3383),
#   tensor(-0.6437)],
#  [tensor(-0.0483),
#   tensor(2.3491),
#   tensor(-1.7560),
#   tensor(0.6461),
#   tensor(-0.0485),
#   tensor(0.9138),
#   tensor(1.2380),
#   tensor(-0.2450),
#   tensor(-2.2469),
#   tensor(0.9892)],
#  [tensor(-0.6211),
#   tensor(-0.6984),
#   tensor(0.2526),
#   tensor(-0.0246),
#   tensor(0.2578),
#   tensor(-0.1536),
#   tensor(0.9492),
#   tensor(-1.6327),
#   tensor(0.9705),
#   tensor(-0.5380)],
#  [tensor(-2.0905),
#   tensor(1.0723),
#   tensor(0.7295),
#   tensor(0.2358),
#   tensor(-0.6042),
#   tensor(1.7510),
#   tensor(1.6980),
#   tensor(-1.1546),
#   tensor(-1.6613),
#   tensor(0.9279)],
#  [tensor(1.0912),
#   tensor(0.5700),
#   tensor(1.6057),
#   tensor(1.8290),
#   tensor(-0.7962),
#   tensor(0.4162),
#   tensor(0.0073),
#   tensor(0.4045),
#   tensor(0.2657),
#   tensor(0.8211)],
#  [tensor(0.3936),
#   tensor(-0.5949),
#   tensor(-0.4190),
#   tensor(-1.3097),
#   tensor(0.9018),
#   tensor(0.5978),
#   tensor(3.0267),
#   tensor(-0.0644),
#   tensor(0.5964),
#   tensor(1.8529)],
#  [tensor(1.7625),
#   tensor(-1.6314),
#   tensor(1.0784),
#   tensor(0.9953),
#   tensor(-0.4087),
#   tensor(-0.4080),
#   tensor(1.3349),
#   tensor(-0.5808),
#   tensor(-1.0027),
#   tensor(-1.0040)],
#  [tensor(0.1728),
#   tensor(-0.0795),
#   tensor(0.8577),
#   tensor(0.4630),
#   tensor(-0.7362),
#   tensor(2.0309),
#   tensor(-0.3335),
#   tensor(-1.1302),
#   tensor(0.2610),
#   tensor(-1.2618)]]

# %%
u = torch.Tensor(t)
u.shape
# Out:
# torch.Size([64, 10])

# %%
u[:, 0]
# Out:
# tensor([-0.4825,  2.4895,  0.1868, -0.3400,  1.4749, -0.8733, -1.6606, -0.6250,
#          0.4397,  0.5244, -0.4976,  1.0539,  0.3110, -1.3516,  0.6474,  0.8936,
#         -0.7166,  0.9896, -1.0928,  1.9672,  1.2015, -1.0657, -0.6052,  1.9592,
#          0.1956, -0.2133,  0.3905,  0.8615,  2.3578,  0.2306,  1.5838, -1.8232,
#          0.2413,  0.0926, -0.1223, -0.8443,  0.5591, -1.2825,  0.8915, -0.9292,
#         -1.5772,  1.5751,  0.3273,  0.6435,  0.0323,  0.8554,  1.7695,  0.1381,
#          0.5394, -0.8951,  1.4777,  0.6707, -1.4706,  0.1517, -0.7286,  0.9210,
#         -0.5989, -0.0483, -0.6211, -2.0905,  1.0912,  0.3936,  1.7625,  0.1728])

# %%
a = torch.Tensor([])
for i in range(0,50,5):
    a = torch.cat((a, torch.Tensor([torch.randn(i)])))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-96fdeaf2f554> in <module>()
#       1 a = torch.Tensor([])
#       2 for i in range(0,50,5):
# ----> 3     a = torch.cat((a, torch.Tensor([torch.randn(i)])))
#
# ValueError: only one element tensors can be converted to Python scalars

# %%
a
# Out:
# tensor([])

# %%
events = tf.range(4, dtype=geom.dtype)
events
# Out:
# <tf.Tensor 'range:0' shape=(4,) dtype=float32>

# %%
probs = geom.prob(events)
probs
# Out:
# <tf.Tensor 'Geometric_31/prob/Exp:0' shape=(4,) dtype=float32>

# %%
a = [t for t in torch.randn(2,5)]

# %%
a
# Out:
# [tensor([ 0.6016,  0.6984, -0.8005,  1.5381,  1.4673]),
#  tensor([ 1.5951, -1.5279,  1.0156, -0.2020, -1.2865])]

# %%
torch.cat(a), a
# Out:
# (tensor([ 0.6016,  0.6984, -0.8005,  1.5381,  1.4673,  1.5951, -1.5279,  1.0156,
#          -0.2020, -1.2865]),
#  [tensor([ 0.6016,  0.6984, -0.8005,  1.5381,  1.4673]),
#   tensor([ 1.5951, -1.5279,  1.0156, -0.2020, -1.2865])])
